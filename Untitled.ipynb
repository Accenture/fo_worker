# %%
import pandas as pd
transactions=pd.read_csv("transaction.csv",header=None)
# t2=pd.read_csv("transactions_data2.csv",header=None)#.set_index('Store')
space=pd.read_csv('fixture.csv',header=None)#.set_index('Store')
brandExit=pd.read_csv('brandExit.csv',header=None)
futureSpace=pd.read_csv('futureSpace.csv',header=None)

# %%
spaceTest=pd.read_csv('fixture.csv',header=0)

# %%
pd.melt(spaceTest,id_vars='Store')
# Out:
#          variable value
# 0      Unnamed: 0     0
# 1      Unnamed: 0     1
# 2      Unnamed: 0     2
# 3      Unnamed: 0     3
# 4      Unnamed: 0     4
# 5      Unnamed: 0     5
# 6      Unnamed: 0     6
# 7      Unnamed: 0     7
# 8      Unnamed: 0     8
# 9      Unnamed: 0     9
# 10     Unnamed: 0    10
# 11     Unnamed: 0    11
# 12     Unnamed: 0    12
# 13     Unnamed: 0    13
# 14     Unnamed: 0    14
# 15     Unnamed: 0    15
# 16     Unnamed: 0    16
# 17     Unnamed: 0    17
# 18     Unnamed: 0    18
# 19     Unnamed: 0    19
# 20     Unnamed: 0    20
# 21     Unnamed: 0    21
# 22     Unnamed: 0    22
# 23     Unnamed: 0    23
# 24     Unnamed: 0    24
# 25     Unnamed: 0    25
# 26     Unnamed: 0    26
# 27     Unnamed: 0    27
# 28     Unnamed: 0    28
# 29     Unnamed: 0    29
# ...           ...   ...
# 21839          17     0
# 21840          17     0
# 21841          17     0
# 21842          17     0
# 21843          17     0
# 21844          17     0
# ...
